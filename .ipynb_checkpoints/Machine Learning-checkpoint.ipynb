# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# from pykalman import KalmanFilter
from statsmodels.nonparametric.smoothers_lowess import lowess
from scipy import signal
import scipy.fftpack
from mpl_toolkits.mplot3d import Axes3D
import datetime
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.pipeline import make_pipeline
import random
from sklearn.model_selection import cross_val_score 
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
import seaborn as sns
from sklearn.ensemble import VotingClassifier,RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Model Functions
# ### `Takes -> `
# ###  `1. X, y and parameters for that model`
# ###  `2. n for n-old cross val score`
# ### `Returns <-
# ### 1. Score for training and validation dat
# ###

# %% [markdown]
# # IT WAS SUPPOSED TO TAKES X AND Y
# ## What function should return
# 1. train score
# 2. test score
# 3. predicited probability array
# 4. cross val score for n folds?

# %%
def voting_classifier_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = VotingClassifier([
        ('nb', GaussianNB()),
        ('knn', KNeighborsClassifier(n_neighbors=12)),
        ('svm', SVC(kernel='linear', C=2.0)),
        ('tree1', DecisionTreeClassifier(max_depth=4)),
        ('tree2', DecisionTreeClassifier(min_samples_leaf=10)),
        ('rfc', RandomForestClassifier(n_estimators=50, max_depth=8))
    ])
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid)
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def random_forest_scores(X, y, n):
    np.random.seed(42)
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        MinMaxScaler(),
        RandomForestClassifier(n_estimators=100, max_depth=10)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def svc_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        StandardScaler(),
        SVC(kernel='linear', C=2.0)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def knn_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        MinMaxScaler(),
        KNeighborsClassifier(n_neighbors=8)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def pca_svc_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        PCA(10),
        SVC(kernel='linear', C=2.0)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def decision_tree_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        MinMaxScaler(),
        DecisionTreeClassifier(max_depth=4)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def nb_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        MinMaxScaler(),
        GaussianNB()
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def nb_with_priors_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        MinMaxScaler(),
        GaussianNB(priors=[25/30, 5/30])
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def gradient_boosting_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        MinMaxScaler(),
        GradientBoostingClassifier(n_estimators=20, max_depth=3, min_samples_leaf=0.3)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def ada_boost_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        MinMaxScaler(),
        AdaBoostClassifier(n_estimators=10, random_state=2)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %%
def mpl_scores(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        MinMaxScaler(),
        MLPClassifier(solver='lbfgs', hidden_layer_sizes=(4,3),
                      learning_rate='adaptive', activation='logistic',
                      max_iter=4000)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted_prob = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    y_predicted = model.predict(X_valid)
    return [t_score, v_score, y_predicted, CVS_mean, y_predicted_prob, y_valid]

# %% [markdown]
# # Best parameter finding for
# 1. Random forest
# 2. svc

# %%
grid = {"n_estimators": [10, 100, 200, 500, 1000, 1200],
        "max_depth": [None, 5, 10, 20, 30],
        "max_features": ["auto", "sqrt"],
        "min_samples_split": [2, 4, 6],
        "min_samples_leaf": [1, 2, 4]}

grid_2 = {'n_estimators': [1200, 1500, 2000],
          'max_depth': [None, 5, 10],
          'max_features': ['auto', 'sqrt'],
          'min_samples_split': [4, 6],
          'min_samples_leaf': [1, 2]}

# %%
def random_forest_BestParam(X, y, n):
    np.random.seed(42)
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    m = RandomForestClassifier(n_estimators=100, max_depth=10)
    
    model = GridSearchCV(estimator=m,
                      param_grid=grid_2,
                      cv=5 # 5-fold cross-validation
                      ) #
    
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    y_predicted = model.predict_proba(X_valid)
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    return [t_score, v_score, y_predicted, CVS_mean, y_valid]

# %%
def svc_scores_BestParam(X, y, n):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model = make_pipeline(
        StandardScaler(),
        SVC(kernel='linear', C=2.0)
    )
    model.fit(X_train, y_train)
    t_score = model.score(X_train, y_train)
    v_score = model.score(X_valid, y_valid) 
    CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
    return [t_score, v_score, y_predicted, CVS_mean, y_valid]

# %% [markdown]
# #  `Import transformed data here`

# %%
walkSit = pd.read_csv("Data/Transformed/walkSit.csv")
walkFall = pd.read_csv("Data/Transformed/walkFall.csv")
runFall = pd.read_csv("Data/Transformed/runFall.csv")
downSit = pd.read_csv("Data/Transformed/downSit.csv")
freeFall = pd.read_csv("Data/Transformed/freeFall.csv")

# %% [markdown]
# #  `Combining Data`

# %%
df = pd.concat([walkSit, walkFall, runFall, downSit, freeFall]).reset_index(drop=True)

# %%
X = df.drop("Fall", axis = 1)
y = df.Fall

# %% [markdown]
# # ROC Curve

# %%
def plot_roc_curve(fpr, tpr, model):
    """
    Input  :  1. False positve rate (fpr) of model 
              2. True postive rate (tpr) of model
              3. Name of model
    Output :  -> Roc Curve plot 
    """
    # Plotting ROC curve
    plt.plot(fpr, tpr, color='red', label='ROC')
    # Plot line with no predictive power (baseline)
    plt.plot([0, 1], [0, 1], color='blue', linestyle='--', label='Guess')
    plt.plot([0, 1], [1, 1], color='orange', linestyle='-.', label='Best')
    plt.plot([0, 0], [0, 1], color='orange', linestyle='-.')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Fall Detection ROC Curve using {model}')
    plt.legend()
    plt.show()

# %% [markdown]
# # Confusion matrix|

# %%
def plot_conf_mat(conf_mat):
    """
    Plots a confusion matrix using Seaborn's heatmap().
    """
    fig, ax = plt.subplots(figsize=(3, 3))
    ax = sns.heatmap(conf_mat,
                     annot=True, # Annotate the boxes 
                     cbar=False)
    plt.xlabel('Predicted label')
    plt.ylabel('True label');

# %%
def print_classification_report(y_test, y_valid):    
    print(pd.DataFrame(classification_report(y_test, y_valid, output_dict=True)))
    
def evaluate_preds(y_true, y_preds):
    """
    Performs evaluation comparison on y_true labels vs. y_pred labels.
    """
    accuracy = accuracy_score(y_true, y_preds)
    precision = precision_score(y_true, y_preds)
    recall = recall_score(y_true, y_preds)
    f1 = f1_score(y_true, y_preds)
    metric_dict = {"accuracy": round(accuracy, 2),
                   "precision": round(precision, 2), 
                   "recall": round(recall, 2),
                   "f1": round(f1, 2)}
    print(f"Acc: {accuracy * 100:.2f}%")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 score: {f1:.2f}")
    
    return metric_dict

# %%
def model_automator(model, n, Model_Name):
    np.random.seed(50)
    
    train_score, test_score, y_predicted, mean_n, y_predicted_prob, y_valid = model(X, y, n)
    print(f"Train data Accuracy                           : {train_score * 100:.2f}%")
    print(f"Test data Accuracy                            : {test_score * 100:.2f}%")
    print(f"{n}-fold Accuracy                               : {mean_n * 100:.2f}%")
    y_predicted_prob = y_predicted_prob[:, 1]
    fpr, tpr, thresholds = roc_curve(y_valid, y_predicted)
    print("Receiver Operating Characteristic (ROC) Score :",roc_auc_score(y_valid, y_predicted_prob))
    plot_roc_curve(fpr,tpr, Model_Name)
    matrix = confusion_matrix(y_valid, y_predicted)
    
    plot_conf_mat(matrix)
    
    print_classification_report(y_valid, y_predicted)

# %% [markdown]
# ###### Finding best parameters??

# %% [markdown]
# # Make the model, train it, whatever

# %% [markdown]
# # `Model Function Calls`

# %% [markdown]
# ## `1.  Voting Classifier`

# %%
np.random.seed(42)
model_automator(random_forest_scores, 5, "Random Forest Classifier")
# Out:
# Train data Accuracy                           : 78.44%
# Test data Accuracy                            : 80.36%
# 5-fold Accuracy                               : 76.10%
# Receiver Operating Characteristic (ROC) Score : 0.506578947368421
#                    0          1  accuracy  macro avg  weighted avg
# precision   0.888889   0.787234  0.803571   0.838061      0.819909
# recall      0.444444   0.973684  0.803571   0.709064      0.803571
# f1-score    0.592593   0.870588  0.803571   0.731590      0.781232
# support    18.000000  38.000000  0.803571  56.000000     56.000000

# %% [markdown]
# ## `2. Random Forest Classifier`

# %%
np.random.seed(42)
model_automator(random_forest_scores, 5, "Random Forest Classifier")
# Out:
# Train data Accuracy                           : 78.44%
# Test data Accuracy                            : 80.36%
# 5-fold Accuracy                               : 76.10%
# Receiver Operating Characteristic (ROC) Score : 0.506578947368421
#                    0          1  accuracy  macro avg  weighted avg
# precision   0.888889   0.787234  0.803571   0.838061      0.819909
# recall      0.444444   0.973684  0.803571   0.709064      0.803571
# f1-score    0.592593   0.870588  0.803571   0.731590      0.781232
# support    18.000000  38.000000  0.803571  56.000000     56.000000

# %% [markdown]
# ## `3. SVC`

# %%
np.random.seed(42)
model_automator(random_forest_scores, 5, "Random Forest Classifier")
# Out:
# Train data Accuracy                           : 78.44%
# Test data Accuracy                            : 80.36%
# 5-fold Accuracy                               : 76.10%
# Receiver Operating Characteristic (ROC) Score : 0.506578947368421
#                    0          1  accuracy  macro avg  weighted avg
# precision   0.888889   0.787234  0.803571   0.838061      0.819909
# recall      0.444444   0.973684  0.803571   0.709064      0.803571
# f1-score    0.592593   0.870588  0.803571   0.731590      0.781232
# support    18.000000  38.000000  0.803571  56.000000     56.000000

# %%
#4. knn
np.random.seed(42)
model_automator(knn_scores, 5, "knn_scores")
# Out:
# Train data Accuracy                           : 77.84%
# Test data Accuracy                            : 83.93%
# 5-fold Accuracy                               : 72.55%
# Receiver Operating Characteristic (ROC) Score : 0.7159090909090909
#                    0          1  accuracy  macro avg  weighted avg
# precision   1.000000   0.790698  0.839286   0.895349      0.872924
# recall      0.590909   1.000000  0.839286   0.795455      0.839286
# f1-score    0.742857   0.883117  0.839286   0.812987      0.828015
# support    22.000000  34.000000  0.839286  56.000000     56.000000

# %%
#5. pca_svc_scores
np.random.seed(42)
model_automator(pca_svc_scores, 5, "pca_svc_scores")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-c4d9f2b9ecab> in <module>
#       1 #5. pca_svc_scores
#       2 np.random.seed(42)
# ----> 3 model_automator(pca_svc_scores, 5, "pca_svc_scores")
#
# <ipython-input-22-da88273f4796> in model_automator(model, n, Model_Name)
#       2     np.random.seed(50)
#       3
# ----> 4     train_score, test_score, y_predicted, mean_n, y_predicted_prob, y_valid = model(X, y, n)
#       5     print(f"Train data Accuracy                           : {train_score * 100:.2f}%")
#       6     print(f"Test data Accuracy                            : {test_score * 100:.2f}%")
#
# <ipython-input-6-dd7bcd7c80fb> in pca_svc_scores(X, y, n)
#       8     t_score = model.score(X_train, y_train)
#       9     v_score = model.score(X_valid, y_valid)
# ---> 10     y_predicted_prob = model.predict_proba(X_valid)
#      11     CVS_mean = np.mean(cross_val_score(model, X, y, cv = n))
#      12     y_predicted = model.predict(X_valid)
#
# D:\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in __get__(self, obj, type)
#     108                     continue
#     109                 else:
# --> 110                     getattr(delegate, self.attribute_name)
#     111                     break
#     112             else:
#
# D:\Anaconda3\lib\site-packages\sklearn\svm\_base.py in predict_proba(self)
#     634         datasets.
#     635         """
# --> 636         self._check_proba()
#     637         return self._predict_proba
#     638
#
# D:\Anaconda3\lib\site-packages\sklearn\svm\_base.py in _check_proba(self)
#     601     def _check_proba(self):
#     602         if not self.probability:
# --> 603             raise AttributeError("predict_proba is not available when "
#     604                                  " probability=False")
#     605         if self._impl not in ('c_svc', 'nu_svc'):
#
# AttributeError: predict_proba is not available when  probability=False

# %%
#6. decision_tree_scores
np.random.seed(42)
model_automator(decision_tree_scores, 5, "decision_tree_scores")
# Out:
# Train data Accuracy                           : 77.25%
# Test data Accuracy                            : 75.00%
# 5-fold Accuracy                               : 73.43%
# Receiver Operating Characteristic (ROC) Score : 0.6176470588235293
#                    0          1  accuracy  macro avg  weighted avg
# precision   0.750000   0.750000      0.75   0.750000      0.750000
# recall      0.545455   0.882353      0.75   0.713904      0.750000
# f1-score    0.631579   0.810811      0.75   0.721195      0.740398
# support    22.000000  34.000000      0.75  56.000000     56.000000

# %%
#7. nb_scores
np.random.seed(42)
model_automator(nb_scores, 5, "nb_scores")
# Out:
# Train data Accuracy                           : 72.46%
# Test data Accuracy                            : 83.93%
# 5-fold Accuracy                               : 69.39%
# Receiver Operating Characteristic (ROC) Score : 0.803475935828877
#                    0          1  accuracy  macro avg  weighted avg
# precision   1.000000   0.790698  0.839286   0.895349      0.872924
# recall      0.590909   1.000000  0.839286   0.795455      0.839286
# f1-score    0.742857   0.883117  0.839286   0.812987      0.828015
# support    22.000000  34.000000  0.839286  56.000000     56.000000

# %%
#8. nb_with_priors_scores
np.random.seed(42)
model_automator(nb_with_priors_scores, 5, "nb_with_priors_scores")
# Out:
# Train data Accuracy                           : 70.66%
# Test data Accuracy                            : 76.79%
# 5-fold Accuracy                               : 67.10%
# Receiver Operating Characteristic (ROC) Score : 0.803475935828877
#                    0          1  accuracy  macro avg  weighted avg
# precision   0.736842   0.783784  0.767857   0.760313      0.765342
# recall      0.636364   0.852941  0.767857   0.744652      0.767857
# f1-score    0.682927   0.816901  0.767857   0.749914      0.764269
# support    22.000000  34.000000  0.767857  56.000000     56.000000

# %%
#9. gradient_boosting_scores
np.random.seed(42)
model_automator(gradient_boosting_scores, 5, "gradient_boosting_scores")
# Out:
# Train data Accuracy                           : 77.84%
# Test data Accuracy                            : 78.57%
# 5-fold Accuracy                               : 72.96%
# Receiver Operating Characteristic (ROC) Score : 0.7259358288770053
#                    0          1  accuracy  macro avg  weighted avg
# precision   0.812500   0.775000  0.785714   0.793750      0.789732
# recall      0.590909   0.911765  0.785714   0.751337      0.785714
# f1-score    0.684211   0.837838  0.785714   0.761024      0.777484
# support    22.000000  34.000000  0.785714  56.000000     56.000000

# %%
#ada 
np.random.seed(42)
model_automator(ada_boost_scores, 5, "ada_boost_scores")
# Out:
# Train data Accuracy                           : 77.25%
# Test data Accuracy                            : 73.21%
# 5-fold Accuracy                               : 72.96%
# Receiver Operating Characteristic (ROC) Score : 0.6163101604278075
#                    0          1  accuracy  macro avg  weighted avg
# precision   0.705882   0.743590  0.732143   0.724736      0.728776
# recall      0.545455   0.852941  0.732143   0.699198      0.732143
# f1-score    0.615385   0.794521  0.732143   0.704953      0.724146
# support    22.000000  34.000000  0.732143  56.000000     56.000000

# %%
np.random.seed(42)
model_automator(mpl_scores, 5, "mpl_scores")
# Out:
# Train data Accuracy                           : 77.84%
# Test data Accuracy                            : 83.93%
# 5-fold Accuracy                               : 73.88%
# Receiver Operating Characteristic (ROC) Score : 0.6430481283422459
#                    0          1  accuracy  macro avg  weighted avg
# precision   1.000000   0.790698  0.839286   0.895349      0.872924
# recall      0.590909   1.000000  0.839286   0.795455      0.839286
# f1-score    0.742857   0.883117  0.839286   0.812987      0.828015
# support    22.000000  34.000000  0.839286  56.000000     56.000000
